# %% [markdown]
# ## Predicting scales and chords of our data at different cardinalities

# %%
from predict_scale import *
from glob import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import seaborn as sns

# %%
scores = glob('./scores/*.mid')
data = {}
for score in scores:
    try:
        data[score] = predict_scale(score, ver_ratio=0.8)
    except:
        print('could not predict')
# Out:
# the most resonant coefficient is:  5
# ./scores\1890Debussy_-_Suite_Bergamasque_-_I._Prelude.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\1890Debussy_-_Suite_Bergamasque_-_II._Menuet.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\1890Debussy_-_Suite_Bergamasque_-_III._Clair_de_Lune.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\1890Debussy_-_Suite_Bergamasque_-_VI._Passepied.mid is a diatonic scale
# could not predict
# the most resonant coefficient is:  5
# ./scores\1891premiere_arabesque.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\1903debussy_estampes_1_(c)galimberti.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\1903estamp2_La soirée_dans_Grenade.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\1903estamp3_Jardins_sous_la_pluie.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\1905estamp1_Pagodes.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\1905images_1_1_(c)oguri.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\1905images_1_2_(c)oguri.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\1905images_1_3_(c)oguri (1).mid is a diatonic scale
# the most resonant coefficient is:  4
# ./scores\1907images_2_1_(c)galimberti.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\1907images_2_2_(c)galimberti.mid is a diatonic scale
# the most resonant coefficient is:  6
# ./scores\1907images_2_3_(c)galimberti.mid is a diatonic scale
# the most resonant coefficient is:  6
# ./scores\1908childrens_corner_1_(c)oguri.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\1908childrens_corner_2_(c)oguri.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\1908childrens_corner_3_(c)oguri.mid is a diatonic scale
# the most resonant coefficient is:  6
# ./scores\1908childrens_corner_4_(c)oguri.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\1908childrens_corner_5_(c)oguri.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\1908childrens_corner_6_(c)dery.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\1910Prélude I - (... Danseuses de delphes).mid is a diatonic scale
# the most resonant coefficient is:  6
# ./scores\1910Prélude II - (... Voiles).mid is a wholetone scale
# the most resonant coefficient is:  5
# ./scores\1910Prélude III - (... Le vent dans la plaine).mid is a diatonic scale
# the most resonant coefficient is:  4
# ./scores\1910Prélude IV - (... Les sons et les parfums tournent dans l'air du soir).mid is a diatonic scale
# the most resonant coefficient is:  3
# ./scores\1910Prélude IX - (... La serenade interrompue).mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\1910Prélude V - (... Les collines d'Anacapri).mid is a diatonic scale
# the most resonant coefficient is:  4
# ./scores\1910Prélude VI - (... Des pas sur la neige).mid is a 6 chromatic tones
# the most resonant coefficient is:  4
# ./scores\1910Prélude VII.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\1910Prélude VIII - (... La fille aux cheveux de lin).mid is a diatonic scale
# the most resonant coefficient is:  3
# ./scores\1910Prélude X - (... La cathedrale engloutie).mid is a diatonic scale
# the most resonant coefficient is:  6
# ./scores\1910Prélude XI.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\1910Prélude XII - (... Minstrels).mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\1913Debussy_Prelude_Book_2_No_10_Canope.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\1913Debussy_Prelude_Book_2_No_11_-_Les_tierces_alternes.mid is a diatonic scale
# the most resonant coefficient is:  2
# ./scores\1913Debussy_Prelude_Book_2_No_12_Feux_dartifice.mid is a diatonic scale
# the most resonant coefficient is:  2
# ./scores\1913Debussy_Prelude_Book_2_No_1_Brouillards.mid is a diatonic scale
# the most resonant coefficient is:  4
# ./scores\1913Debussy_Prelude_Book_2_No_2_Feuilles_mortes.mid is a diatonic scale
# the most resonant coefficient is:  4
# ./scores\1913Debussy_Prelude_Book_2_No_3_La_puerta_del_vino.mid is a diatonic scale
# the most resonant coefficient is:  6
# ./scores\1913Debussy_Prelude_Book_2_No_4_Les_fees_sont_dexquises_danseuses.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\1913Debussy_Prelude_Book_2_No_5_Bruyres.mid is a diatonic scale
# the most resonant coefficient is:  4
# ./scores\1913Debussy_Prelude_Book_2_No_6_General_Lavine_-_excentric.mid is a diatonic scale
# the most resonant coefficient is:  6
# ./scores\1913Debussy_Prelude_Book_2_No_7_La_terrasse_des_audiences_du_clair_de_lune.mid is a diatonic scale
# the most resonant coefficient is:  6
# ./scores\1913Debussy_Prelude_Book_2_No_8_Ondine.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\1913Debussy_Prelude_Book_2_No_9_Hommage_a_S._Pickwick_Esq._P._P._M._P._C.mid is a diatonic scale

# %%
coeffs = [d[0] for d in data.values()]
plt.hist(coeffs, bins=6)
plt.title('Distribution of most resonant coefficients at the top of level of the piece')
# Out:
# Text(0.5, 1.0, 'Distribution of most resonant coefficients at the top of level of the piece')

# %%
scores = glob('./scores2/suite_bergamasque 1890+1891/*.mid')
data = {}
for score in scores:
    try:
        data[score] = predict_scale(score, ver_ratio=(0.8,1))
    except:
        print('could not predict')
# Out:
# the most resonant coefficient is:  5
# ./scores2/suite_bergamasque 1890+1891\Debussy_-_Suite_Bergamasque_-_II._Menuet.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores2/suite_bergamasque 1890+1891\Debussy_-_Suite_Bergamasque_-_III._Clair_de_Lune.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores2/suite_bergamasque 1890+1891\Debussy_-_Suite_Bergamasque_-_VI._Passepied.mid is a diatonic scale
# could not predict
# the most resonant coefficient is:  5
# ./scores2/suite_bergamasque 1890+1891\premiere_arabesque.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores2/suite_bergamasque 1890+1891\Suite_bergamasque_Prelude.mid is a diatonic scale

# %%
coeffs = [d[0] for d in data.values()]
plt.hist(coeffs, bins=6)
plt.title('Distribution of most resonant coefficients at the top of level of the piece- early ')
# Out:
# Text(0.5, 1.0, 'Distribution of most resonant coefficients at the top of level of the piece- early ')

# %%
scores = glob('./scores2/preludes/*.mid')
data = {}
for score in scores:
    try:
        data[score] = predict_scale(score, ver_ratio=(0.8,1))
    except:
        print('could not predict')
# Out:
# the most resonant coefficient is:  5
# ./scores2/preludes\Debussy_Prelude_Book_2_No_10_Canope.mid is a pentatonic scale
# the most resonant coefficient is:  5
# ./scores2/preludes\Debussy_Prelude_Book_2_No_11_-_Les_tierces_alternes.mid is a diatonic scale
# the most resonant coefficient is:  2
# ./scores2/preludes\Debussy_Prelude_Book_2_No_12_Feux_dartifice.mid is a diatonic scale
# the most resonant coefficient is:  2
# ./scores2/preludes\Debussy_Prelude_Book_2_No_1_Brouillards.mid is a diatonic scale
# the most resonant coefficient is:  4
# ./scores2/preludes\Debussy_Prelude_Book_2_No_2_Feuilles_mortes.mid is a diatonic scale
# the most resonant coefficient is:  4
# ./scores2/preludes\Debussy_Prelude_Book_2_No_3_La_puerta_del_vino.mid is a diatonic scale
# the most resonant coefficient is:  6
# ./scores2/preludes\Debussy_Prelude_Book_2_No_4_Les_fees_sont_dexquises_danseuses.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores2/preludes\Debussy_Prelude_Book_2_No_5_Bruyres.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores2/preludes\Debussy_Prelude_Book_2_No_6_General_Lavine_-_excentric.mid is a pentatonic scale
# the most resonant coefficient is:  6
# ./scores2/preludes\Debussy_Prelude_Book_2_No_7_La_terrasse_des_audiences_du_clair_de_lune.mid is a diatonic scale
# the most resonant coefficient is:  4
# ./scores2/preludes\Debussy_Prelude_Book_2_No_8_Ondine.mid is a pentatonic scale
# the most resonant coefficient is:  5
# ./scores2/preludes\Debussy_Prelude_Book_2_No_9_Hommage_a_S._Pickwick_Esq._P._P._M._P._C.mid is a diatonic scale
# the most resonant coefficient is:  1
# ./scores2/preludes\Prélude I - (... Danseuses de delphes).mid is a tritone
# the most resonant coefficient is:  6
# ./scores2/preludes\Prélude II - (... Voiles).mid is a half dim chord
# the most resonant coefficient is:  5
# ./scores2/preludes\Prélude III - (... Le vent dans la plaine).mid is a pentatonic scale
# the most resonant coefficient is:  4
# ./scores2/preludes\Prélude IV - (... Les sons et les parfums tournent dans l'air du soir).mid is a pentatonic scale
# the most resonant coefficient is:  3
# ./scores2/preludes\Prélude IX - (... La serenade interrompue).mid is a major/minor triad
# the most resonant coefficient is:  5
# ./scores2/preludes\Prélude V - (... Les collines d'Anacapri).mid is a major/minor triad
# the most resonant coefficient is:  4
# ./scores2/preludes\Prélude VI - (... Des pas sur la neige).mid is a pentatonic scale
# the most resonant coefficient is:  4
# ./scores2/preludes\Prélude VII.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores2/preludes\Prélude VIII - (... La fille aux cheveux de lin).mid is a major/minor triad
# the most resonant coefficient is:  3
# ./scores2/preludes\Prélude X - (... La cathedrale engloutie).mid is a diatonic scale
# the most resonant coefficient is:  6
# ./scores2/preludes\Prélude XI.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores2/preludes\Prélude XII - (... Minstrels).mid is a pentatonic scale

# %%
coeffs = [d[0] for d in data.values()]
plt.hist(coeffs, bins=6)
plt.title('Distribution of most resonant coefficients at the top of level of the piece-preludes')
# Out:
# Text(0.5, 1.0, 'Distribution of most resonant coefficients at the top of level of the piece-preludes')

# %%
data = {}
for score in scores:
    try:
        data[score] = predict_scale(score, ver_ratio=(0,0.2))
    except:
        print('could not predict')
# Out:
# the most resonant coefficient is:  5
# ./scores\childrens_corner_1_(c)oguri.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\childrens_corner_2_(c)oguri.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\childrens_corner_3_(c)oguri.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\childrens_corner_4_(c)oguri.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\childrens_corner_5_(c)oguri.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\childrens_corner_6_(c)dery.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\Debussy_-_Suite_Bergamasque_-_I._Prelude.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\Debussy_-_Suite_Bergamasque_-_II._Menuet.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\Debussy_-_Suite_Bergamasque_-_III._Clair_de_Lune.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\Debussy_-_Suite_Bergamasque_-_VI._Passepied.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\debussy_estampes_1_(c)galimberti.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\Debussy_Prelude_Book_2_No_10_Canope.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\Debussy_Prelude_Book_2_No_11_-_Les_tierces_alternes.mid is a diatonic scale
# the most resonant coefficient is:  1
# ./scores\Debussy_Prelude_Book_2_No_12_Feux_dartifice.mid is a diatonic scale
# the most resonant coefficient is:  1
# ./scores\Debussy_Prelude_Book_2_No_1_Brouillards.mid is a tritone
# the most resonant coefficient is:  1
# ./scores\Debussy_Prelude_Book_2_No_2_Feuilles_mortes.mid is a tritone
# the most resonant coefficient is:  4
# ./scores\Debussy_Prelude_Book_2_No_3_La_puerta_del_vino.mid is a diatonic scale
# the most resonant coefficient is:  6
# ./scores\Debussy_Prelude_Book_2_No_4_Les_fees_sont_dexquises_danseuses.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\Debussy_Prelude_Book_2_No_5_Bruyres.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\Debussy_Prelude_Book_2_No_6_General_Lavine_-_excentric.mid is a diatonic scale
# the most resonant coefficient is:  1
# ./scores\Debussy_Prelude_Book_2_No_7_La_terrasse_des_audiences_du_clair_de_lune.mid is a tritone
# the most resonant coefficient is:  3
# ./scores\Debussy_Prelude_Book_2_No_8_Ondine.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\Debussy_Prelude_Book_2_No_9_Hommage_a_S._Pickwick_Esq._P._P._M._P._C.mid is a diatonic scale
# could not predict
# the most resonant coefficient is:  5
# ./scores\estamp1_Pagodes.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\estamp2_La soirée_dans_Grenade.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\estamp3_Jardins_sous_la_pluie.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\images_1_1_(c)oguri.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\images_1_2_(c)oguri.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\images_1_3_(c)oguri (1).mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\images_2_1_(c)galimberti.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\images_2_2_(c)galimberti.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\images_2_3_(c)galimberti.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\premiere_arabesque.mid is a hexatonic scale
# the most resonant coefficient is:  1
# ./scores\Prélude I - (... Danseuses de delphes).mid is a tritone
# the most resonant coefficient is:  1
# ./scores\Prélude II - (... Voiles).mid is a tritone
# the most resonant coefficient is:  5
# ./scores\Prélude III - (... Le vent dans la plaine).mid is a diatonic scale
# the most resonant coefficient is:  4
# ./scores\Prélude IV - (... Les sons et les parfums tournent dans l'air du soir).mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\Prélude IX - (... La serenade interrompue).mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\Prélude V - (... Les collines d'Anacapri).mid is a diatonic scale
# the most resonant coefficient is:  4
# ./scores\Prélude VI - (... Des pas sur la neige).mid is a diatonic scale
# the most resonant coefficient is:  6
# ./scores\Prélude VII.mid is a diatonic scale
# the most resonant coefficient is:  1
# ./scores\Prélude VIII - (... La fille aux cheveux de lin).mid is a tritone
# the most resonant coefficient is:  5
# ./scores\Prélude X - (... La cathedrale engloutie).mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\Prélude XI.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores\Prélude XII - (... Minstrels).mid is a diatonic scale

# %%
coeffs = [d[0] for d in data.values()]
plt.hist(coeffs, bins=6)
plt.title('Distribution of most resonant coefficients at the lowest of level of the piece')
# Out:
# Text(0.5, 1.0, 'Distribution of most resonant coefficients at the lowest of level of the piece')

# %%
scores = glob('./scores2/suite_bergamasque 1890+1891/*.mid')
data = {}
for score in scores:
    try:
        data[score] = predict_scale(score, ver_ratio=(0.2,1))
    except:
        print('could not predict')
# Out:
# the most resonant coefficient is:  5
# ./scores2/suite_bergamasque 1890+1891\Debussy_-_Suite_Bergamasque_-_II._Menuet.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores2/suite_bergamasque 1890+1891\Debussy_-_Suite_Bergamasque_-_III._Clair_de_Lune.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores2/suite_bergamasque 1890+1891\Debussy_-_Suite_Bergamasque_-_VI._Passepied.mid is a diatonic scale
# could not predict
# the most resonant coefficient is:  5
# ./scores2/suite_bergamasque 1890+1891\premiere_arabesque.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores2/suite_bergamasque 1890+1891\Suite_bergamasque_Prelude.mid is a diatonic scale

# %%
coeffs = [d[0] for d in data.values()]
plt.hist(coeffs, bins=6)
plt.title('Distribution of most resonant coefficients at the lowest of level of the piece-early')
# Out:
# Text(0.5, 1.0, 'Distribution of most resonant coefficients at the lowest of level of the piece-early')

# %%
scores = glob('./scores2/preludes/*.mid')
data = {}
for score in scores:
    try:
        data[score] = predict_scale(score, ver_ratio=(0.2,1))
    except:
        print('could not predict')
# Out:
# the most resonant coefficient is:  5
# ./scores2/preludes\Debussy_Prelude_Book_2_No_10_Canope.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores2/preludes\Debussy_Prelude_Book_2_No_11_-_Les_tierces_alternes.mid is a diatonic scale
# the most resonant coefficient is:  2
# ./scores2/preludes\Debussy_Prelude_Book_2_No_12_Feux_dartifice.mid is a diatonic scale
# the most resonant coefficient is:  2
# ./scores2/preludes\Debussy_Prelude_Book_2_No_1_Brouillards.mid is a diatonic scale
# the most resonant coefficient is:  4
# ./scores2/preludes\Debussy_Prelude_Book_2_No_2_Feuilles_mortes.mid is a diatonic scale
# the most resonant coefficient is:  4
# ./scores2/preludes\Debussy_Prelude_Book_2_No_3_La_puerta_del_vino.mid is a diatonic scale
# the most resonant coefficient is:  6
# ./scores2/preludes\Debussy_Prelude_Book_2_No_4_Les_fees_sont_dexquises_danseuses.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores2/preludes\Debussy_Prelude_Book_2_No_5_Bruyres.mid is a diatonic scale
# the most resonant coefficient is:  4
# ./scores2/preludes\Debussy_Prelude_Book_2_No_6_General_Lavine_-_excentric.mid is a diatonic scale
# the most resonant coefficient is:  6
# ./scores2/preludes\Debussy_Prelude_Book_2_No_7_La_terrasse_des_audiences_du_clair_de_lune.mid is a diatonic scale
# the most resonant coefficient is:  4
# ./scores2/preludes\Debussy_Prelude_Book_2_No_8_Ondine.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores2/preludes\Debussy_Prelude_Book_2_No_9_Hommage_a_S._Pickwick_Esq._P._P._M._P._C.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores2/preludes\Prélude I - (... Danseuses de delphes).mid is a diatonic scale
# the most resonant coefficient is:  6
# ./scores2/preludes\Prélude II - (... Voiles).mid is a half dim chord
# the most resonant coefficient is:  5
# ./scores2/preludes\Prélude III - (... Le vent dans la plaine).mid is a diatonic scale
# the most resonant coefficient is:  4
# ./scores2/preludes\Prélude IV - (... Les sons et les parfums tournent dans l'air du soir).mid is a diatonic scale
# the most resonant coefficient is:  3
# ./scores2/preludes\Prélude IX - (... La serenade interrompue).mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores2/preludes\Prélude V - (... Les collines d'Anacapri).mid is a diatonic scale
# the most resonant coefficient is:  4
# ./scores2/preludes\Prélude VI - (... Des pas sur la neige).mid is a diatonic scale
# the most resonant coefficient is:  4
# ./scores2/preludes\Prélude VII.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores2/preludes\Prélude VIII - (... La fille aux cheveux de lin).mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores2/preludes\Prélude X - (... La cathedrale engloutie).mid is a diatonic scale
# the most resonant coefficient is:  6
# ./scores2/preludes\Prélude XI.mid is a diatonic scale
# the most resonant coefficient is:  5
# ./scores2/preludes\Prélude XII - (... Minstrels).mid is a diatonic scale

# %%
coeffs = [d[0] for d in data.values()]
plt.hist(coeffs, bins=6)
plt.title('Distribution of most resonant coefficients at the lowest of level of the piece-preludes')
# Out:
# Text(0.5, 1.0, 'Distribution of most resonant coefficients at the lowest of level of the piece-preludes')

# %%
scores = glob('./scores2/preludes/*.mid')
data = {}
for score in scores:
    try:
        data[score] = predict_scale(score, ver_ratio=(0.5,1))
    except:
        print('could not predict')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bf6b26f45750> in <module>
# ----> 1 scores = glob('./scores2/preludes/*.mid')
#       2 data = {}
#       3 for score in scores:
#       4     try:
#       5         data[score] = predict_scale(score, ver_ratio=(0.5,1))
#
# NameError: name 'glob' is not defined

# %%
coeffs = [d[0] for d in data.values()]
plt.hist(coeffs, bins=6)
plt.title('Distribution of most resonant coefficients at the mid level of the piece-preludes')
# Out:
# Text(0.5, 1.0, 'Distribution of most resonant coefficients at the mid level of the piece-preludes')

# %%
coeffs = [d[1] for d in data.values() if d[0] == 5]
plt.hist(coeffs, bins=6)
plt.title('Distribution of predicted pentatonic vs diatonic at the top level of the piece')
# Out:
# Text(0.5, 1.0, 'Distribution of predicted pentatonic vs diatonic at the top level of the piece')

# %%
# Create data
x = range(1,len(scores))
y = [] 
coeffs = [d[2] for d in data.values()]
cfr = pd.DataFrame(coeffs)
coeffs_perc = cfr.divide(cfr.sum(axis=1), axis=0)
#pal = sns.color_palette("Set1")
for i in range(6):
    y.append(coeffs_perc[i])
    
# Basic stacked area chart.
plt.stackplot(x,y[0],y[1], y[2],y[3],y[4],y[5], labels=['1','2','3','4','5','6'])
plt.legend(loc='upper right')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-67e28a1e16dc> in <module>
#      12 plt.stackplot(x,y[0],y[1], y[2],y[3],y[4],y[5], labels=['1','2','3','4','5','6'])
#      13 plt.legend(loc='upper right')
# ---> 14 ax.set_xticks([2,4,6,8,10])
#
# NameError: name 'ax' is not defined

# %%
coeffs = [d[2] for d in data.values()]
print(coeffs)

lst2 = [item[0] for item in coeffs]
print(lst2)
# Out:
# [array([0.19355218, 0.21283849, 0.205362  , 0.19935768, 0.28163396,
#        0.19830245]), array([0.16326695, 0.16831391, 0.17139003, 0.16035688, 0.22502211,
#        0.16211522]), array([0.21271815, 0.21256253, 0.24059407, 0.21231276, 0.3246751 ,
#        0.21315051]), array([0.20018613, 0.21325949, 0.20528319, 0.21270063, 0.2688565 ,
#        0.20750003]), array([0.19835548, 0.20797452, 0.22933866, 0.19781042, 0.29047813,
#        0.19498756]), array([0.25678385, 0.28041512, 0.27847705, 0.27360818, 0.39276125,
#        0.25311231]), array([0.20238589, 0.20123357, 0.21765684, 0.1985175 , 0.25490955,
#        0.23282345]), array([0.21744626, 0.21910297, 0.20068368, 0.21950118, 0.22457451,
#        0.19363541]), array([0.2651493 , 0.29356601, 0.27068175, 0.27706853, 0.39724284,
#        0.25149393]), array([0.19716556, 0.19596512, 0.22601939, 0.20042203, 0.2509539 ,
#        0.21204718]), array([0.18156335, 0.19059538, 0.18446262, 0.18126251, 0.21715006,
#        0.17017632]), array([0.24053781, 0.25660234, 0.22472662, 0.21899671, 0.26945253,
#        0.25360028]), array([0.17809192, 0.19458673, 0.18267942, 0.22649928, 0.21493107,
#        0.19349335]), array([0.1725961 , 0.16685122, 0.18722895, 0.19213922, 0.20191552,
#        0.19424638]), array([0.1679454 , 0.17508934, 0.17779512, 0.17535907, 0.19286931,
#        0.19508094]), array([0.19471081, 0.21586278, 0.22358812, 0.20890461, 0.24551819,
#        0.25179088]), array([0.23080861, 0.25070381, 0.22531616, 0.25271313, 0.29783932,
#        0.25551696]), array([0.19412658, 0.19696397, 0.19935335, 0.21789383, 0.24759652,
#        0.18044451]), array([0.23062692, 0.20054   , 0.23423647, 0.22051259, 0.2455853 ,
#        0.2516465 ]), array([0.18888406, 0.20348566, 0.17952101, 0.19878325, 0.21377717,
#        0.17452098]), array([0.22106194, 0.19760738, 0.21848436, 0.20108159, 0.27165494,
#        0.24361444]), array([0.18847405, 0.19652358, 0.22044969, 0.20562923, 0.32215294,
#        0.21802084]), array([0.27514866, 0.26468393, 0.26515491, 0.25260829, 0.3171812 ,
#        0.49215467]), array([0.23474063, 0.22320218, 0.23938875, 0.21715783, 0.24625094,
#        0.20195667]), array([0.18723764, 0.19709887, 0.23412275, 0.24050511, 0.20428006,
#        0.2100439 ]), array([0.21219949, 0.24944043, 0.25972492, 0.2106711 , 0.25049311,
#        0.22694213]), array([0.29189114, 0.29759041, 0.32674678, 0.32314626, 0.40744571,
#        0.27831848]), array([0.22927668, 0.20158531, 0.236516  , 0.27758415, 0.21373446,
#        0.18941137]), array([0.18279384, 0.19652728, 0.19836129, 0.22213026, 0.19574635,
#        0.17853393]), array([0.19515466, 0.24202842, 0.29925911, 0.24778083, 0.38216441,
#        0.19771436]), array([0.18439338, 0.20961403, 0.21592157, 0.19757557, 0.21138788,
#        0.20877695]), array([0.19945102, 0.21410726, 0.18957198, 0.19845038, 0.20760713,
#        0.24036466]), array([0.20774647, 0.23663358, 0.21188181, 0.20715361, 0.25560381,
#        0.21863623]), array([0.18934568, 0.2244916 , 0.19776206, 0.20830556, 0.28090865,
#        0.21391785]), array([0.17056291, 0.17161344, 0.18297861, 0.17972582, 0.20755229,
#        0.17808656]), array([0.16588179, 0.16777762, 0.15615539, 0.14294973, 0.16159307,
#        0.14576262]), array([0.19936359, 0.30823935, 0.20076763, 0.21717797, 0.25533128,
#        0.1715595 ]), array([0.18549774, 0.17239158, 0.19825014, 0.22326497, 0.19140031,
#        0.17648094]), array([0.17162463, 0.19429157, 0.21452964, 0.23430941, 0.2129258 ,
#        0.17283491]), array([0.25204229, 0.19592991, 0.20837139, 0.20081054, 0.22783068,
#        0.28792774]), array([0.17066228, 0.19555302, 0.17803318, 0.1737639 , 0.30797631,
#        0.17648465]), array([0.19536354, 0.21218052, 0.19711657, 0.23649331, 0.23571467,
#        0.22164347]), array([0.16844641, 0.19088558, 0.18159354, 0.21988438, 0.18382144,
#        0.22337745]), array([0.20507783, 0.23568462, 0.2350915 , 0.25420326, 0.21621325,
#        0.2522764 ]), array([0.15837928, 0.16740344, 0.17805706, 0.16844217, 0.29767357,
#        0.16414472])]
# [0.1935521835374243, 0.16326695384611928, 0.21271814673723602, 0.20018613047796413, 0.19835548118076843, 0.2567838461921369, 0.20238589311950675, 0.21744625646112295, 0.26514929561747835, 0.1971655636395482, 0.18156335381482772, 0.24053780810064124, 0.17809191918763495, 0.17259610228143768, 0.1679454009022, 0.19471080856539819, 0.23080861317065038, 0.1941265763273743, 0.2306269243147983, 0.18888406461076274, 0.22106193511644942, 0.18847405100760306, 0.2751486567219131, 0.23474063017738608, 0.18723764373510107, 0.2121994906805507, 0.2918911363504095, 0.22927667583181305, 0.18279383899113777, 0.19515465664958784, 0.18439337858887803, 0.1994510236300844, 0.20774647117053607, 0.18934567644929215, 0.17056290862869952, 0.16588178620896868, 0.19936359151716024, 0.18549773639282424, 0.17162463165089353, 0.25204228995646555, 0.17066228202140926, 0.19536354453548663, 0.16844640831265587, 0.20507783469796367, 0.15837927555956122]
